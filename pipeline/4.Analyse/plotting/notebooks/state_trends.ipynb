# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from pathlib import Path

# %%
# ==== UPDATED FILE PATHS ====
cveg_trendy_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/cVeg/ENSMEAN/ENSMEAN_S3_cVeg.nc"
csoil_trendy_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/cSoil/ENSMEAN/ENSMEAN_S3_cSoil.nc"
clitter_trendy_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/cLitter/ENSMEAN/ENSMEAN_S3_cLitter.nc"
lai_trendy_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/lai/ENSMEAN/ENSMEAN_S3_lai.nc"
mrso_trendy_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/mrso/ENSMEAN/ENSMEAN_S3_mrso.nc"

cveg_emu_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/MODELS/32_year/cVeg.nc"
csoil_emu_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/MODELS/32_year/cSoil.nc"
clitter_emu_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/MODELS/32_year/cLitter.nc"
lai_emu_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/MODELS/32_year/lai.nc"
mrso_emu_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/MODELS/32_year/mrso.nc"

cveg_base_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/carry_distances/MODELS/base_model/S3/cVeg.nc"
csoil_base_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/carry_distances/MODELS/base_model/S3/cSoil.nc"
clitter_base_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/carry_distances/MODELS/base_model/S3/cLitter.nc"
lai_base_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/carry_distances/MODELS/base_model/S3/lai.nc"
mrso_base_S3_path = "/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/carry_distances/MODELS/base_model/S3/mrso.nc"

# ==== LOAD TRENDY ====
cveg_trendy = xr.open_dataset(cveg_trendy_S3_path)['cVeg']
csoil_trendy = xr.open_dataset(csoil_trendy_S3_path)['cSoil']
clitter_trendy = xr.open_dataset(clitter_trendy_S3_path)['cLitter']
lai_trendy = xr.open_dataset(lai_trendy_S3_path)['lai']
mrso_trendy = xr.open_dataset(mrso_trendy_S3_path)['mrso']

# ==== LOAD EMULATOR ====
cveg_emu = xr.open_dataset(cveg_emu_S3_path)['cVeg']
csoil_emu = xr.open_dataset(csoil_emu_S3_path)['cSoil']
clitter_emu = xr.open_dataset(clitter_emu_S3_path)['cLitter']
lai_emu = xr.open_dataset(lai_emu_S3_path)['lai']
mrso_emu = xr.open_dataset(mrso_emu_S3_path)['mrso']

# ==== LOAD EMULATOR ====
cveg_emu = xr.open_dataset(cveg_base_S3_path)['cVeg']
csoil_emu = xr.open_dataset(csoil_base_S3_path)['cSoil']
clitter_emu = xr.open_dataset(clitter_base_S3_path)['cLitter']
lai_emu = xr.open_dataset(lai_base_S3_path)['lai']
mrso_emu = xr.open_dataset(mrso_base_S3_path)['mrso']

# ==== MASK + CAST ====
cveg_trendy_f = cveg_trendy.where(np.isfinite(cveg_trendy)).astype("float32")
csoil_trendy_f = csoil_trendy.where(np.isfinite(csoil_trendy)).astype("float32")
clitter_trendy_f = clitter_trendy.where(np.isfinite(clitter_trendy)).astype("float32")
lai_trendy_f = lai_trendy.where(np.isfinite(lai_trendy)).astype("float32")
mrso_trendy_f = mrso_trendy.where(np.isfinite(mrso_trendy)).astype("float32")

cveg_emu_f = cveg_emu.where(np.isfinite(cveg_emu)).astype("float32")
csoil_emu_f = csoil_emu.where(np.isfinite(csoil_emu)).astype("float32")
clitter_emu_f = clitter_emu.where(np.isfinite(clitter_emu)).astype("float32")
lai_emu_f = lai_emu.where(np.isfinite(lai_emu)).astype("float32")
mrso_emu_f = mrso_emu.where(np.isfinite(mrso_emu)).astype("float32")

cveg_base_f = cveg_emu.where(np.isfinite(cveg_emu)).astype("float32")
csoil_base_f = csoil_emu.where(np.isfinite(csoil_emu)).astype("float32")
clitter_base_f = clitter_emu.where(np.isfinite(clitter_emu)).astype("float32")
lai_base_f = lai_emu.where(np.isfinite(lai_emu)).astype("float32")
mrso_base_f = mrso_emu.where(np.isfinite(mrso_emu)).astype("float32")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniconda3/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Net/Groups/BGI/people/ecathain/TRENDY_Emulator_Scripts/NewModel/pipeline/3.benchmark/ilamb/benchmarks/32_year_vs_ensmean_scenarios/S3/DATA/cVeg/ENSMEAN/ENSMEAN_S3_cVeg.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '96e38ed4-2b8c-4c90-bd29-11685c02058f']
#
# ...

# %%
def xr_linear_trend_years(da: xr.DataArray, time_dim: str = "time") -> xr.DataArray:
    """
    Linear trend per grid cell along <time_dim>, in units per year.

    Assumes:
      - <time_dim> is datetime-like (cftime or numpy datetime)
      - calendar is effectively noleap, but only year + dayofyear are used.
    """
    time = da[time_dim]

    # fractional year: year + (doy-1)/365
    years = time.dt.year.astype("float64") + (
        time.dt.dayofyear.astype("float64") - 1.0
    ) / 365.0
    t = xr.DataArray(years, dims=time_dim)

    t_centered = t - t.mean(dim=time_dim)
    da_centered = da - da.mean(dim=time_dim)

    slope = (da_centered * t_centered).sum(dim=time_dim) / (t_centered**2).sum(dim=time_dim)

    if da.name:
        slope = slope.rename(da.name + "_trend")
    return slope

def trend_lai_or_mrso(da: xr.DataArray, time_dim: str = "time") -> xr.DataArray:
    """
    Remove monthly climatology, then compute linear trend per year.
    """
    clim = da.groupby(f"{time_dim}.month").mean(dim=time_dim)
    anomalies = da.groupby(f"{time_dim}.month") - clim
    return xr_linear_trend_years(anomalies, time_dim=time_dim)

def annual_mean_trend(da: xr.DataArray, time_dim: str = "time") -> xr.DataArray:
    """
    Take annual mean first, then compute linear trend per year.
    """
    # groupby year → da_ann has dimension 'year'
    da_ann = da.groupby(f"{time_dim}.year").mean(dim=time_dim)

    # ensure 'year' is a coordinate (it already is, but cast to float for safety)
    da_ann = da_ann.assign_coords(year=da_ann["year"].astype("float64"))

    return xr_linear_trend_over_year_coord(da_ann, year_dim="year")

def xr_linear_trend_over_year_coord(da: xr.DataArray, year_dim: str = "year") -> xr.DataArray:
    """
    Linear trend per grid cell along a numeric 'year' coordinate.
    da[year_dim] must be 1D and numeric (e.g. 1901, 1902, ...).
    """
    years = da[year_dim].astype("float64")
    t = xr.DataArray(years, dims=year_dim)

    t_centered = t - t.mean(dim=year_dim)
    da_centered = da - da.mean(dim=year_dim)

    slope = (da_centered * t_centered).sum(dim=year_dim) / (t_centered**2).sum(dim=year_dim)

    if da.name:
        slope = slope.rename(da.name + "_trend")
    return slope

# %%
cveg_trendy_trend    = annual_mean_trend(cveg_trendy_f)
csoil_trendy_trend   = annual_mean_trend(csoil_trendy_f)
clitter_trendy_trend = annual_mean_trend(clitter_trendy_f)
lai_trendy_trend = trend_lai_or_mrso(lai_trendy_f)
mrso_trendy_trend = trend_lai_or_mrso(mrso_trendy_f)

# %%
cveg_emu_trend    = annual_mean_trend(cveg_emu_f)
csoil_emu_trend   = annual_mean_trend(csoil_emu_f)
clitter_emu_trend = annual_mean_trend(clitter_emu_f)
lai_emu_trend    = trend_lai_or_mrso(lai_emu_f)
mrso_emu_trend    = trend_lai_or_mrso(mrso_emu_f)

# %%
cveg_base_trend    = annual_mean_trend(cveg_base_f)
csoil_base_trend   = annual_mean_trend(csoil_base_f)
clitter_base_trend = annual_mean_trend(clitter_base_f)
lai_base_trend   = trend_lai_or_mrso(lai_base_f)
mrso_base_trend   = trend_lai_or_mrso(mrso_base_f)

# %%
cveg_base_bias = cveg_trendy_trend - cveg_base_trend
csoil_base_bias = csoil_trendy_trend - csoil_base_trend
clitter_base_bias = clitter_trendy_trend - clitter_base_trend
lai_base_bias = lai_trendy_trend - lai_base_trend
mrso_base_bias = mrso_trendy_trend - mrso_base_trend

cveg_emu_bias = cveg_trendy_trend - cveg_emu_trend
csoil_emu_bias = csoil_trendy_trend - csoil_emu_trend
clitter_emu_bias = clitter_trendy_trend - clitter_emu_trend
lai_emu_bias = lai_trendy_trend - lai_emu_trend
mrso_emu_bias = mrso_trendy_trend - mrso_emu_trend

# %%
trendy_trends = {
    "cVeg":    cveg_trendy_trend,
    "cSoil":   csoil_trendy_trend,
    "cLitter": clitter_trendy_trend,
    "lai":     lai_trendy_trend,
    "mrso":    mrso_trendy_trend,
}

stable_trends = {
    "cVeg":    cveg_emu_trend,
    "cSoil":   csoil_emu_trend,
    "cLitter": clitter_emu_trend,
    "lai":     lai_emu_trend,
    "mrso":    mrso_emu_trend,
}

base_trends = {
    "cVeg":    cveg_base_trend,
    "cSoil":   csoil_base_trend,
    "cLitter": clitter_base_trend,
    "lai":     lai_base_trend,
    "mrso":    mrso_base_trend,
}

trendy_biases = {
    "cVeg":    cveg_base_bias,
    "cSoil":   csoil_base_bias,
    "cLitter": clitter_base_bias,
    "lai":     lai_base_bias,
    "mrso":    mrso_base_bias,
}

stable_biases = {
    "cVeg":    cveg_emu_bias,
    "cSoil":   csoil_emu_bias,
    "cLitter": clitter_emu_bias,
    "lai":     lai_emu_bias,
    "mrso":    mrso_emu_bias,
}
